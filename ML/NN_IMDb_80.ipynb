# %% [markdown]
# # **How to decide what to watch on Netflix? - Neural Network**
#
# New movies come out on Netflix every month, some I have never heard of. Is it possible to build a model that will tell me if a movie is worth watching based on a subset of movie parameters?

# %%
import pandas as pd

# %%
df = pd.read_csv("../Resources/cleaned_data.csv")
df.head()
# Out:
#                             Title  Year  Age  IMDb  Rotten Tomatoes  Netflix  \
# 0                       Inception  2010  13+   8.8              8.7        1
# 1                      The Matrix  1999  18+   8.7              8.7        1
# 2          Avengers: Infinity War  2018  13+   8.5              8.4        1
# 3              Back to the Future  1985   7+   8.5              9.6        1
# 4  The Good, the Bad and the Ugly  1966  18+   8.8              9.7        1
#
#    Hulu  Prime Video  Disney+                       Directors  \
# 0     0            0        0               Christopher Nolan
# 1     0            0        0  Lana Wachowski,Lilly Wachowski
# 2     0            0        0         Anthony Russo,Joe Russo
# 3     0            0        0                 Robert Zemeckis
# 4     0            1        0                    Sergio Leone
#
#                              Genres        Country  Runtime  \
# 0  Action,Adventure,Sci-Fi,Thriller  United States    148.0
# 1                     Action,Sci-Fi  United States    136.0
# 2           Action,Adventure,Sci-Fi  United States    149.0
# 3           Adventure,Comedy,Sci-Fi  United States    116.0
# 4                           Western          Italy    161.0
#
#   production_company Top_Genres       Top_Director
# 0       Warner Bros.     Action  Christopher Nolan
# 1                NaN     Action     Lana Wachowski
# 2                NaN     Action      Anthony Russo
# 3                NaN  Adventure    Robert Zemeckis
# 4                NaN    Western       Sergio Leone

# %%
df = df[["Year", "Country", "Runtime", "Top_Genres", "IMDb"]]
df = df.rename(columns={"Top_Genres":"Genre"})
df = df.dropna()
df["Runtime"] = df[["Runtime"]].round(0).astype(int)
df["IMDb"] = (df["IMDb"]*10).round(0).astype(int)
df.head()
# Out:
#    Year        Country  Runtime      Genre  IMDb
# 0  2010  United States      148     Action    88
# 1  1999  United States      136     Action    87
# 2  2018  United States      149     Action    85
# 3  1985  United States      116  Adventure    85
# 4  1966          Italy      161    Western    88

# %%
cleanup_genre = {"Genre": {'Action': 5, 'Adventure': 5, 'Western': 3, 'Animation': 7, 'Biography': 1,
       'Drama': 8, 'Crime': 5, 'Comedy': 4, 'Documentary': 1, 'Family': 8, 'Horror': 6,
       'Thriller': 5, 'Mystery': 5, 'Fantasy': 7, 'Romance': 8, 'Short': 7, 'Sci-Fi': 6,
       'Sport': 2, 'Reality-TV': 4, 'Musical': 7, 'Music': 7, 'War': 3, 'History': 1,
       'Film-Noir': 6, 'Talk-Show': 4, 'Game-Show': 4}}

# %%
df = df.replace(cleanup_genre)
df.head()
# Out:
#    Year        Country  Runtime  Genre  IMDb
# 0  2010  United States      148      5    88
# 1  1999  United States      136      5    87
# 2  2018  United States      149      5    85
# 3  1985  United States      116      5    85
# 4  1966          Italy      161      3    88

# %%
df.loc[df["Country"] == "United States", "Country"] = 1
df.loc[df["Country"] != 1, "Country"] = 0
df["Country"] = df["Country"].astype(int)
df.head()
# Out:
#    Year  Country  Runtime  Genre  IMDb
# 0  2010        1      148      5    88
# 1  1999        1      136      5    87
# 2  2018        1      149      5    85
# 3  1985        1      116      5    85
# 4  1966        0      161      3    88

# %%
df.loc[df["IMDb"] < 80, "IMDb"] = 0
df.loc[df["IMDb"] >= 80, "IMDb"] = 1
df.head()
# Out:
#    Year  Country  Runtime  Genre  IMDb
# 0  2010        1      148      5     1
# 1  1999        1      136      5     1
# 2  2018        1      149      5     1
# 3  1985        1      116      5     1
# 4  1966        0      161      3     1

# %%
data = df.drop("IMDb", axis=1)
target = df["IMDb"].values.reshape(-1, 1)
print(data.shape, target.shape)
# Out:
# (15699, 4) (15699, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from tensorflow.keras.utils import to_categorical
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential()
model.add(Dense(units=10, activation="relu", input_dim=4))
model.add(Dense(units=2, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                50
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 22
# =================================================================
# Total params: 72
# Trainable params: 72
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit(X_train_scaled, y_train_categorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 368/368 - 1s - loss: 0.2703 - accuracy: 0.9400
# Epoch 2/100
# 368/368 - 0s - loss: 0.1606 - accuracy: 0.9640
# Epoch 3/100
# 368/368 - 0s - loss: 0.1513 - accuracy: 0.9640
# Epoch 4/100
# 368/368 - 0s - loss: 0.1464 - accuracy: 0.9640
# Epoch 5/100
# 368/368 - 0s - loss: 0.1434 - accuracy: 0.9638
# Epoch 6/100
# 368/368 - 0s - loss: 0.1416 - accuracy: 0.9639
# Epoch 7/100
# 368/368 - 0s - loss: 0.1403 - accuracy: 0.9640
# Epoch 8/100
# 368/368 - 0s - loss: 0.1402 - accuracy: 0.9637
# Epoch 9/100
# 368/368 - 0s - loss: 0.1395 - accuracy: 0.9638
# Epoch 10/100
# 368/368 - 0s - loss: 0.1392 - accuracy: 0.9639
# Epoch 11/100
# 368/368 - 0s - loss: 0.1390 - accuracy: 0.9639
# Epoch 12/100
# 368/368 - 0s - loss: 0.1384 - accuracy: 0.9639
# Epoch 13/100
# 368/368 - 0s - loss: 0.1385 - accuracy: 0.9638
# Epoch 14/100
# 368/368 - 0s - loss: 0.1381 - accuracy: 0.9639
# Epoch 15/100
# 368/368 - 0s - loss: 0.1378 - accuracy: 0.9638
# Epoch 16/100
# 368/368 - 0s - loss: 0.1376 - accuracy: 0.9638
# Epoch 17/100
# 368/368 - 0s - loss: 0.1375 - accuracy: 0.9638
# Epoch 18/100
# 368/368 - 0s - loss: 0.1374 - accuracy: 0.9639
# Epoch 19/100
# 368/368 - 0s - loss: 0.1371 - accuracy: 0.9638
# Epoch 20/100
# 368/368 - 0s - loss: 0.1369 - accuracy: 0.9639
# Epoch 21/100
# 368/368 - 0s - loss: 0.1367 - accuracy: 0.9638
# Epoch 22/100
# 368/368 - 0s - loss: 0.1368 - accuracy: 0.9639
# Epoch 23/100
# 368/368 - 0s - loss: 0.1364 - accuracy: 0.9640
# Epoch 24/100
# 368/368 - 0s - loss: 0.1365 - accuracy: 0.9638
# Epoch 25/100
# 368/368 - 0s - loss: 0.1361 - accuracy: 0.9639
# Epoch 26/100
# 368/368 - 0s - loss: 0.1358 - accuracy: 0.9639
# Epoch 27/100
# 368/368 - 0s - loss: 0.1360 - accuracy: 0.9639
# Epoch 28/100
# 368/368 - 0s - loss: 0.1359 - accuracy: 0.9639
# Epoch 29/100
# 368/368 - 0s - loss: 0.1357 - accuracy: 0.9640
# Epoch 30/100
# 368/368 - 0s - loss: 0.1356 - accuracy: 0.9639
# Epoch 31/100
# 368/368 - 0s - loss: 0.1354 - accuracy: 0.9640
# Epoch 32/100
# 368/368 - 0s - loss: 0.1356 - accuracy: 0.9639
# Epoch 33/100
# 368/368 - 0s - loss: 0.1353 - accuracy: 0.9639
# Epoch 34/100
# 368/368 - 0s - loss: 0.1349 - accuracy: 0.9640
# Epoch 35/100
# 368/368 - 0s - loss: 0.1349 - accuracy: 0.9640
# Epoch 36/100
# 368/368 - 0s - loss: 0.1347 - accuracy: 0.9640
# Epoch 37/100
# 368/368 - 0s - loss: 0.1348 - accuracy: 0.9640
# Epoch 38/100
# 368/368 - 0s - loss: 0.1344 - accuracy: 0.9640
# Epoch 39/100
# 368/368 - 0s - loss: 0.1344 - accuracy: 0.9640
# Epoch 40/100
# 368/368 - 0s - loss: 0.1346 - accuracy: 0.9638
# Epoch 41/100
# 368/368 - 0s - loss: 0.1343 - accuracy: 0.9640
# Epoch 42/100
# 368/368 - 0s - loss: 0.1345 - accuracy: 0.9638
# Epoch 43/100
# 368/368 - 0s - loss: 0.1339 - accuracy: 0.9640
# Epoch 44/100
# 368/368 - 0s - loss: 0.1341 - accuracy: 0.9639
# Epoch 45/100
# 368/368 - 0s - loss: 0.1341 - accuracy: 0.9639
# Epoch 46/100
# 368/368 - 0s - loss: 0.1338 - accuracy: 0.9640
# Epoch 47/100
# 368/368 - 0s - loss: 0.1340 - accuracy: 0.9639
# Epoch 48/100
# 368/368 - 0s - loss: 0.1336 - accuracy: 0.9640
# Epoch 49/100
# 368/368 - 0s - loss: 0.1340 - accuracy: 0.9640
# Epoch 50/100
# 368/368 - 0s - loss: 0.1336 - accuracy: 0.9639
# Epoch 51/100
# 368/368 - 0s - loss: 0.1334 - accuracy: 0.9640
# Epoch 52/100
# 368/368 - 0s - loss: 0.1338 - accuracy: 0.9640
# Epoch 53/100
# 368/368 - 0s - loss: 0.1339 - accuracy: 0.9639
# Epoch 54/100
# 368/368 - 0s - loss: 0.1333 - accuracy: 0.9640
# Epoch 55/100
# 368/368 - 0s - loss: 0.1336 - accuracy: 0.9640
# Epoch 56/100
# 368/368 - 0s - loss: 0.1335 - accuracy: 0.9639
# Epoch 57/100
# 368/368 - 0s - loss: 0.1334 - accuracy: 0.9639
# Epoch 58/100
# 368/368 - 0s - loss: 0.1333 - accuracy: 0.9640
# Epoch 59/100
# 368/368 - 0s - loss: 0.1333 - accuracy: 0.9640
# Epoch 60/100
# 368/368 - 0s - loss: 0.1333 - accuracy: 0.9640
# Epoch 61/100
# 368/368 - 0s - loss: 0.1330 - accuracy: 0.9640
# Epoch 62/100
# 368/368 - 0s - loss: 0.1332 - accuracy: 0.9640
# Epoch 63/100
# 368/368 - 0s - loss: 0.1332 - accuracy: 0.9640
# Epoch 64/100
# 368/368 - 0s - loss: 0.1329 - accuracy: 0.9640
# Epoch 65/100
# 368/368 - 0s - loss: 0.1330 - accuracy: 0.9640
# Epoch 66/100
# 368/368 - 0s - loss: 0.1330 - accuracy: 0.9639
# Epoch 67/100
# 368/368 - 0s - loss: 0.1331 - accuracy: 0.9640
# Epoch 68/100
# 368/368 - 0s - loss: 0.1330 - accuracy: 0.9640
# Epoch 69/100
# 368/368 - 0s - loss: 0.1331 - accuracy: 0.9639
# Epoch 70/100
# 368/368 - 0s - loss: 0.1329 - accuracy: 0.9640
# Epoch 71/100
# 368/368 - 0s - loss: 0.1328 - accuracy: 0.9640
# Epoch 72/100
# 368/368 - 0s - loss: 0.1327 - accuracy: 0.9640
# Epoch 73/100
# 368/368 - 0s - loss: 0.1327 - accuracy: 0.9640
# Epoch 74/100
# 368/368 - 0s - loss: 0.1326 - accuracy: 0.9640
# Epoch 75/100
# 368/368 - 0s - loss: 0.1327 - accuracy: 0.9640
# Epoch 76/100
# 368/368 - 0s - loss: 0.1325 - accuracy: 0.9640
# Epoch 77/100
# 368/368 - 0s - loss: 0.1325 - accuracy: 0.9640
# Epoch 78/100
# 368/368 - 0s - loss: 0.1325 - accuracy: 0.9640
# Epoch 79/100
# 368/368 - 0s - loss: 0.1326 - accuracy: 0.9640
# Epoch 80/100
# 368/368 - 0s - loss: 0.1326 - accuracy: 0.9640
# Epoch 81/100
# 368/368 - 0s - loss: 0.1324 - accuracy: 0.9640
# Epoch 82/100
# 368/368 - 0s - loss: 0.1328 - accuracy: 0.9639
# Epoch 83/100
# 368/368 - 0s - loss: 0.1324 - accuracy: 0.9640
# Epoch 84/100
# 368/368 - 0s - loss: 0.1328 - accuracy: 0.9640
# Epoch 85/100
# 368/368 - 0s - loss: 0.1324 - accuracy: 0.9639
# Epoch 86/100
# 368/368 - 0s - loss: 0.1324 - accuracy: 0.9640
# Epoch 87/100
# 368/368 - 0s - loss: 0.1322 - accuracy: 0.9640
# Epoch 88/100
# 368/368 - 0s - loss: 0.1325 - accuracy: 0.9640
# Epoch 89/100
# 368/368 - 0s - loss: 0.1323 - accuracy: 0.9640
# Epoch 90/100
# 368/368 - 0s - loss: 0.1322 - accuracy: 0.9640
# Epoch 91/100
# 368/368 - 0s - loss: 0.1322 - accuracy: 0.9640
# Epoch 92/100
# 368/368 - 0s - loss: 0.1323 - accuracy: 0.9640
# Epoch 93/100
# 368/368 - 0s - loss: 0.1323 - accuracy: 0.9640
# Epoch 94/100
# 368/368 - 0s - loss: 0.1324 - accuracy: 0.9640
# Epoch 95/100
# 368/368 - 0s - loss: 0.1320 - accuracy: 0.9640
# Epoch 96/100
# 368/368 - 0s - loss: 0.1320 - accuracy: 0.9639
# Epoch 97/100
# 368/368 - 0s - loss: 0.1320 - accuracy: 0.9640
# Epoch 98/100
# 368/368 - 0s - loss: 0.1320 - accuracy: 0.9640
# Epoch 99/100
# 368/368 - 0s - loss: 0.1320 - accuracy: 0.9640
# Epoch 100/100
# 368/368 - 0s - loss: 0.1322 - accuracy: 0.9640

# %%
deep_model = Sequential()
deep_model.add(Dense(units=10, activation="relu", input_dim=4))
deep_model.add(Dense(units=10, activation="relu"))
deep_model.add(Dense(units=2, activation="softmax"))

# %%
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 10)                50
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 22
# =================================================================
# Total params: 182
# Trainable params: 182
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

deep_model.fit(X_train_scaled, y_train_categorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 368/368 - 1s - loss: 0.2562 - accuracy: 0.9507
# Epoch 2/100
# 368/368 - 0s - loss: 0.1544 - accuracy: 0.9640
# Epoch 3/100
# 368/368 - 0s - loss: 0.1467 - accuracy: 0.9640
# Epoch 4/100
# 368/368 - 0s - loss: 0.1434 - accuracy: 0.9640
# Epoch 5/100
# 368/368 - 0s - loss: 0.1414 - accuracy: 0.9640
# Epoch 6/100
# 368/368 - 0s - loss: 0.1402 - accuracy: 0.9640
# Epoch 7/100
# 368/368 - 0s - loss: 0.1394 - accuracy: 0.9640
# Epoch 8/100
# 368/368 - 0s - loss: 0.1387 - accuracy: 0.9640
# Epoch 9/100
# 368/368 - 0s - loss: 0.1379 - accuracy: 0.9640
# Epoch 10/100
# 368/368 - 0s - loss: 0.1375 - accuracy: 0.9640
# Epoch 11/100
# 368/368 - 0s - loss: 0.1370 - accuracy: 0.9640
# Epoch 12/100
# 368/368 - 0s - loss: 0.1370 - accuracy: 0.9640
# Epoch 13/100
# 368/368 - 0s - loss: 0.1363 - accuracy: 0.9640
# Epoch 14/100
# 368/368 - 0s - loss: 0.1364 - accuracy: 0.9639
# Epoch 15/100
# 368/368 - 0s - loss: 0.1361 - accuracy: 0.9640
# Epoch 16/100
# 368/368 - 0s - loss: 0.1359 - accuracy: 0.9640
# Epoch 17/100
# 368/368 - 0s - loss: 0.1355 - accuracy: 0.9640
# Epoch 18/100
# 368/368 - 0s - loss: 0.1353 - accuracy: 0.9640
# Epoch 19/100
# 368/368 - 0s - loss: 0.1357 - accuracy: 0.9640
# Epoch 20/100
# 368/368 - 0s - loss: 0.1355 - accuracy: 0.9639
# Epoch 21/100
# 368/368 - 0s - loss: 0.1351 - accuracy: 0.9640
# Epoch 22/100
# 368/368 - 0s - loss: 0.1352 - accuracy: 0.9639
# Epoch 23/100
# 368/368 - 0s - loss: 0.1349 - accuracy: 0.9639
# Epoch 24/100
# 368/368 - 0s - loss: 0.1346 - accuracy: 0.9639
# Epoch 25/100
# 368/368 - 0s - loss: 0.1344 - accuracy: 0.9639
# Epoch 26/100
# 368/368 - 0s - loss: 0.1345 - accuracy: 0.9640
# Epoch 27/100
# 368/368 - 0s - loss: 0.1344 - accuracy: 0.9639
# Epoch 28/100
# 368/368 - 0s - loss: 0.1342 - accuracy: 0.9639
# Epoch 29/100
# 368/368 - 0s - loss: 0.1343 - accuracy: 0.9639
# Epoch 30/100
# 368/368 - 0s - loss: 0.1339 - accuracy: 0.9641
# Epoch 31/100
# 368/368 - 0s - loss: 0.1341 - accuracy: 0.9639
# Epoch 32/100
# 368/368 - 0s - loss: 0.1336 - accuracy: 0.9638
# Epoch 33/100
# 368/368 - 0s - loss: 0.1339 - accuracy: 0.9640
# Epoch 34/100
# 368/368 - 0s - loss: 0.1334 - accuracy: 0.9639
# Epoch 35/100
# 368/368 - 0s - loss: 0.1337 - accuracy: 0.9638
# Epoch 36/100
# 368/368 - 0s - loss: 0.1334 - accuracy: 0.9639
# Epoch 37/100
# 368/368 - 0s - loss: 0.1332 - accuracy: 0.9637
# Epoch 38/100
# 368/368 - 0s - loss: 0.1333 - accuracy: 0.9640
# Epoch 39/100
# 368/368 - 0s - loss: 0.1335 - accuracy: 0.9639
# Epoch 40/100
# 368/368 - 0s - loss: 0.1333 - accuracy: 0.9638
# Epoch 41/100
# 368/368 - 0s - loss: 0.1327 - accuracy: 0.9641
# Epoch 42/100
# 368/368 - 0s - loss: 0.1327 - accuracy: 0.9637
# Epoch 43/100
# 368/368 - 0s - loss: 0.1332 - accuracy: 0.9639
# Epoch 44/100
# 368/368 - 0s - loss: 0.1329 - accuracy: 0.9639
# Epoch 45/100
# 368/368 - 0s - loss: 0.1328 - accuracy: 0.9639
# Epoch 46/100
# 368/368 - 0s - loss: 0.1328 - accuracy: 0.9640
# Epoch 47/100
# 368/368 - 0s - loss: 0.1327 - accuracy: 0.9639
# Epoch 48/100
# 368/368 - 0s - loss: 0.1327 - accuracy: 0.9640
# Epoch 49/100
# 368/368 - 0s - loss: 0.1329 - accuracy: 0.9640
# Epoch 50/100
# 368/368 - 0s - loss: 0.1323 - accuracy: 0.9639
# Epoch 51/100
# 368/368 - 0s - loss: 0.1328 - accuracy: 0.9637
# Epoch 52/100
# 368/368 - 0s - loss: 0.1322 - accuracy: 0.9639
# Epoch 53/100
# 368/368 - 0s - loss: 0.1328 - accuracy: 0.9640
# Epoch 54/100
# 368/368 - 0s - loss: 0.1324 - accuracy: 0.9639
# Epoch 55/100
# 368/368 - 0s - loss: 0.1323 - accuracy: 0.9642
# Epoch 56/100
# 368/368 - 0s - loss: 0.1324 - accuracy: 0.9639
# Epoch 57/100
# 368/368 - 0s - loss: 0.1321 - accuracy: 0.9640
# Epoch 58/100
# 368/368 - 0s - loss: 0.1324 - accuracy: 0.9639
# Epoch 59/100
# 368/368 - 0s - loss: 0.1324 - accuracy: 0.9642
# Epoch 60/100
# 368/368 - 0s - loss: 0.1323 - accuracy: 0.9640
# Epoch 61/100
# 368/368 - 0s - loss: 0.1323 - accuracy: 0.9642
# Epoch 62/100
# 368/368 - 0s - loss: 0.1319 - accuracy: 0.9640
# Epoch 63/100
# 368/368 - 0s - loss: 0.1324 - accuracy: 0.9637
# Epoch 64/100
# 368/368 - 0s - loss: 0.1327 - accuracy: 0.9636
# Epoch 65/100
# 368/368 - 0s - loss: 0.1322 - accuracy: 0.9640
# Epoch 66/100
# 368/368 - 0s - loss: 0.1321 - accuracy: 0.9639
# Epoch 67/100
# 368/368 - 0s - loss: 0.1325 - accuracy: 0.9639
# Epoch 68/100
# 368/368 - 0s - loss: 0.1320 - accuracy: 0.9640
# Epoch 69/100
# 368/368 - 0s - loss: 0.1321 - accuracy: 0.9640
# Epoch 70/100
# 368/368 - 0s - loss: 0.1318 - accuracy: 0.9641
# Epoch 71/100
# 368/368 - 0s - loss: 0.1316 - accuracy: 0.9640
# Epoch 72/100
# 368/368 - 0s - loss: 0.1319 - accuracy: 0.9642
# Epoch 73/100
# 368/368 - 0s - loss: 0.1321 - accuracy: 0.9642
# Epoch 74/100
# 368/368 - 0s - loss: 0.1319 - accuracy: 0.9640
# Epoch 75/100
# 368/368 - 0s - loss: 0.1322 - accuracy: 0.9641
# Epoch 76/100
# 368/368 - 0s - loss: 0.1317 - accuracy: 0.9640
# Epoch 77/100
# 368/368 - 0s - loss: 0.1318 - accuracy: 0.9643
# Epoch 78/100
# 368/368 - 0s - loss: 0.1318 - accuracy: 0.9639
# Epoch 79/100
# 368/368 - 0s - loss: 0.1322 - accuracy: 0.9641
# Epoch 80/100
# 368/368 - 0s - loss: 0.1318 - accuracy: 0.9639
# Epoch 81/100
# 368/368 - 0s - loss: 0.1322 - accuracy: 0.9638
# Epoch 82/100
# 368/368 - 0s - loss: 0.1320 - accuracy: 0.9638
# Epoch 83/100
# 368/368 - 0s - loss: 0.1317 - accuracy: 0.9642
# Epoch 84/100
# 368/368 - 0s - loss: 0.1316 - accuracy: 0.9640
# Epoch 85/100
# 368/368 - 0s - loss: 0.1316 - accuracy: 0.9636
# Epoch 86/100
# 368/368 - 0s - loss: 0.1319 - accuracy: 0.9640
# Epoch 87/100
# 368/368 - 0s - loss: 0.1317 - accuracy: 0.9639
# Epoch 88/100
# 368/368 - 0s - loss: 0.1312 - accuracy: 0.9639
# Epoch 89/100
# 368/368 - 0s - loss: 0.1320 - accuracy: 0.9641
# Epoch 90/100
# 368/368 - 0s - loss: 0.1315 - accuracy: 0.9640
# Epoch 91/100
# 368/368 - 0s - loss: 0.1318 - accuracy: 0.9638
# Epoch 92/100
# 368/368 - 0s - loss: 0.1318 - accuracy: 0.9638
# Epoch 93/100
# 368/368 - 0s - loss: 0.1318 - accuracy: 0.9639
# Epoch 94/100
# 368/368 - 0s - loss: 0.1319 - accuracy: 0.9638
# Epoch 95/100
# 368/368 - 0s - loss: 0.1315 - accuracy: 0.9639
# Epoch 96/100
# 368/368 - 0s - loss: 0.1317 - accuracy: 0.9641
# Epoch 97/100
# 368/368 - 0s - loss: 0.1316 - accuracy: 0.9641
# Epoch 98/100
# 368/368 - 0s - loss: 0.1315 - accuracy: 0.9637
# Epoch 99/100
# 368/368 - 0s - loss: 0.1314 - accuracy: 0.9638
# Epoch 100/100
# 368/368 - 0s - loss: 0.1314 - accuracy: 0.9641

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 123/123 - 0s - loss: 0.1428 - accuracy: 0.9610
# Loss: 0.14284873008728027, Accuracy: 0.9610190987586975

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 123/123 - 0s - loss: 0.1451 - accuracy: 0.9597
# Deep Neural Network - Loss: 0.1451275497674942, Accuracy: 0.9597452282905579
